# %%
import numpy as np
import pandas as pd

#Import dataset

strikers_data= pd.read_csv('C:/Users/jesus/OneDrive/Documentos/STRIKERS_DATA_2.csv')  
print(strikers_data)
# Out:
#     Player_ID  SHIRT_N  AGE  HEIGHT  FOOT  SQUAD_RANKING  OPPONENT RANKING  \
# 0        PT-7        7   19     187     1              9                18
# 1        PT-7        7   19     187     1              9                32
# 2        PT-7        7   19     187     1              9                 5
# 3        PT-7        7   19     187     1              9                 8
# 4        PT-7        7   19     187     1              9                 6
# ..        ...      ...  ...     ...   ...            ...               ...
# 986      UA-9        9   27     184     1             22                65
# 987      UA-9        9   27     184     1             22               172
# 988      UA-9        9   27     184     1             22                 9
# 989      UA-9        9   27     184     1             22                74
# 990      UA-9        9   27     184     1             22                72
#
# ...

# %%
sd_1=strikers_data.drop(columns=['Player_ID'])
print(sd_1)
correlation_matrix = sd_1.corr()
# Out:
#      SHIRT_N  AGE  HEIGHT  FOOT  SQUAD_RANKING  OPPONENT RANKING  M_WEEKDAY  \
# 0          7   19     187     1              9                18          7
# 1          7   19     187     1              9                32          4
# 2          7   19     187     1              9                 5          1
# 3          7   19     187     1              9                 8          5
# 4          7   19     187     1              9                 6          4
# ..       ...  ...     ...   ...            ...               ...        ...
# 986        9   27     184     1             22                65          7
# 987        9   27     184     1             22               172          3
# 988        9   27     184     1             22                 9          2
# 989        9   27     184     1             22                74          5
# 990        9   27     184     1             22                72          3
#
# ...

# %%
corr_style = correlation_matrix.style.background_gradient(cmap='coolwarm')
corr_style
# Out:
# <style type="text/css">
# #T_f0041_row0_col0, #T_f0041_row1_col1, #T_f0041_row2_col2, #T_f0041_row3_col3, #T_f0041_row4_col4, #T_f0041_row5_col5, #T_f0041_row6_col6, #T_f0041_row7_col7, #T_f0041_row8_col8, #T_f0041_row9_col9, #T_f0041_row10_col10, #T_f0041_row11_col11, #T_f0041_row12_col12, #T_f0041_row13_col13, #T_f0041_row14_col14, #T_f0041_row15_col15, #T_f0041_row16_col16, #T_f0041_row17_col17, #T_f0041_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f0041_row0_col1, #T_f0041_row0_col3, #T_f0041_row0_col15, #T_f0041_row0_col16, #T_f0041_row0_col17, #T_f0041_row1_col0, #T_f0041_row2_col4, #T_f0041_row2_col9, #T_f0041_row2_col13, #T_f0041_row4_col2, #T_f0041_row4_col14, #T_f0041_row4_col15, #T_f0041_row4_col18, #T_f0041_row5_col10, #T_f0041_row5_col11, #T_f0041_row5_col12, #T_f0041_row9_col6, #T_f0041_row9_col7, #T_f0041_row9_col8, #T_f0041_row12_col5, #T_f0041_row14_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# ...
